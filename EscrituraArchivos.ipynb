# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianEduardoMendez/programacion1/blob/main/EscrituraArchivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("archivo.txt", "w") as f:
  f.write("Hola, este es un archivo de texto.\n")
  f.write("Segunda linea.")

# %%
with open("archivo.txt", "r") as f:
  print(f.read())
# Out:
# Hola, este es un archivo de texto.
# Segunda linea.

# %%
from google.colab import files
files.download("archivo.txt")

# %%
with open("archivo.txt", "a") as f:
  f.write("\nEsta es una nueva línea añadida.")

# %%
with open("archivo.txt", "r") as f:
  print(f.read())
# Out:
# Hola, este es un archivo de texto.
# Segunda linea.
# Esta es una nueva línea añadida.

# %%
with open("ejemplo.txt", "w") as f:
  f.write("Este es un ejemplo \nHola")

# %%
with open("ejemplo.txt", "r") as f:
  print(f.read())
# Out:
# Este es un ejemplo
# Hola

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1aec9708-a68b-47ae-ab4b-206c0d5175f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1aec9708-a68b-47ae-ab4b-206c0d5175f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("archivo (1).txt", "r") as f:
  print(f.read())
# Out:
# Hola, este es un archivo de texto.
# Segunda linea.

# %%
with open("platillo.txt", "w") as f:
  f.write("Este archivo fue completamente modificado\n")
  f.write("Nueva línea\n")
  f.write("Nueva línea2\n")

# %%
with open("platillo.txt", "r") as f:
  print(f.read())
# Out:
# Este archivo fue completamente modificado
# Nueva línea
# Nueva línea2

# %%
from google.colab import files
files.download("platillo.txt")

# %% [markdown]
# CSV

# %%
import csv
datos = [["Nombre", "Edad", "Ciudad"], ["Ana", 25, "Bogotá"], ["Luis", 30, "Medelín"], ["Carlos", 28, "Cali"]]
with open("datos.csv", "w", newline="") as f:
  writer = csv.writer(f)
  writer.writerows(datos)

# %%
with open("datos.csv", "r") as f:
  print(f.read())
# Out:
# Nombre,Edad,Ciudad
# Ana,25,Bogotá
# Luis,30,Medelín
# Carlos,28,Cali

# %%
files.download("datos.csv")

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
ruta = "/content/drive/MyDrive/datos.csv"
import shutil as st
st.copy("datos.csv", ruta)
# Out:
# '/content/drive/MyDrive/datos.csv'

# %%
with open(ruta, "r") as f:
  print(f.read())
# Out:
# Nombre,Edad,Ciudad
# Ana,25,Bogotá
# Luis,30,Medelín
# Carlos,28,Cali

# %%
with open(ruta, "r") as f:
  data = list(csv.reader(f))

data.append(["Diego", "28", "Armenia"])
data
# Out:
# [['Nombre', 'Edad', 'Ciudad'],
#  ['Ana', '25', 'Bogotá'],
#  ['Luis', '30', 'Medelín'],
#  ['Carlos', '28', 'Cali'],
#  ['Diego', '28', 'Armenia']]

# %%
import pandas as pd
data1 = pd.DataFrame(data)
data1
# Out:
#         0     1        2
# 0  Nombre  Edad   Ciudad
# 1     Ana    25   Bogotá
# 2    Luis    30  Medelín
# 3  Carlos    28     Cali
# 4   Diego    28  Armenia

# %%
import csv

ruta = "/content/drive/MyDrive/datos.csv"

# Leer
with open(ruta, "r") as f:
    data = list(csv.reader(f))

# Mostrar antes
print("ANTES:")
print(data)

# Agregar fila
data.append(["Diego", "28", "Armenia"])

# Guardar
with open(ruta, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(data)

# Mostrar después
print("\nDESPUÉS:")
with open(ruta, "r") as f:
    print(f.read())
# Out:
# ANTES:
# [['Nombre', 'Edad', 'Ciudad'], ['Ana', '25', 'Bogotá'], ['Luis', '30', 'Medelín'], ['Carlos', '28', 'Cali']]
#
# DESPUÉS:
# Nombre,Edad,Ciudad
# Ana,25,Bogotá
# Luis,30,Medelín
# Carlos,28,Cali
# Diego,28,Armenia

# %%
import os
os.listdir("/content/drive/MyDrive")
# Out:
# ['Colab Notebooks',
#  'EVIDENCE CLASS 1 (2).pdf',
#  'EVIDENCE CLASS 1 (1).pdf',
#  'EVIDENCE CLASS 1.pdf',
#  'Classroom',
#  'MY ACTIVITY (2).docx',
#  'MY ACTIVITY (1).docx',
#  'MY ACTIVITY.docx',
#  'atg-discuss-will (1).gdoc',
#  'PROYECT PART 1 PRETENAGEARS 10 (1).docx',
#  'LISTENING EXERCISE.docx',
#  'MY EVIDENCE  xd.docx',
#  'PROYECT PART 1 PRETENAGEARS 10.docx',
#  'Doc2Myactivity qwq.docx',
#  'top006-describing-people.gdoc',
#  'lota Hurricane.gslides',
#  'DOC-20221007-WA0014. (1).pdf',
#  'DOC-20221007-WA0014..pdf',
#  'factorización caso 3 y 4.pdf',
#  'Untitled folder',
#  'Trabajo, matemáticas videos',
#  'INFORMATICA 11-1',
#  'Sena video',
#  'PORTAFOLIO JULIAN MENDEZ',
#  'SAMUEL CUEVAS RAMIREZ.pdf',
#  'Formulario sin título (3).gform',
#  'Evaluación de matemáticas 11-1.gform',
#  'Pedraza2823_343434.docx',
#  '5 carta carnet.docx',
#  'Formulario sin título (2).gform',
#  'Formulario sin título (1).gform',
#  'Formulario sin título.gform',
# ...

# %%
import pandas as pd
df = pd.read_csv(ruta)
df
# Out:
#    Nombre  Edad   Ciudad
# 0     Ana    25   Bogotá
# 1    Luis    30  Medelín
# 2  Carlos    28     Cali
# 3   Diego    28  Armenia

# %%
df["Nueva_Columna"] = "valor"
df["Nueva_Columna"] = [10, 20, 30, None]
df
# Out:
#    Nombre  Edad   Ciudad  Nueva_Columna
# 0     Ana    25   Bogotá           10.0
# 1    Luis    30  Medelín           20.0
# 2  Carlos    28     Cali           30.0
# 3   Diego    28  Armenia            NaN
